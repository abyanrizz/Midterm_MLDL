# %% [markdown]
# <a href="https://colab.research.google.com/github/abyanrizz/Midterm_MLDL/blob/main/03.clustering/01.middterm_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install gdown if not already installed
# !pip install -U -q gdown

# %%
# Replace 'your_folder_id' with the actual folder ID
folder_id = '18Q0DAlWETJW60Pe3fNwnneX5aOtvrkoK'

# Download all files from the specified Google Drive folder
# The `--folder` flag indicates that the ID belongs to a folder
# The `--id` flag is for the folder ID
# The `--output` flag (optional) can specify a directory to save files,
# but by default, it will download to the current directory.
print(f"Downloading files from folder ID: {folder_id}")
# !gdown --folder --id {folder_id}

print("Download complete. You can list the files in the current directory to see the downloaded content.")
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Retrieving folder contents
# Processing file 1DN3RXJkWNEbDSRhhDiFZ8L3L9OZ1m0mt clusteringmidterm.csv
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1DN3RXJkWNEbDSRhhDiFZ8L3L9OZ1m0mt
# To: /content/clustering /clusteringmidterm.csv
# 100% 1.01M/1.01M [00:00<00:00, 107MB/s]
# Download completed
# Download complete. You can list the files in the current directory to see the downloaded content.

# %%
import pandas as pd

df = pd.read_csv('clustering /clusteringmidterm.csv')
display(df.head())
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df.info()
df.describe()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df_clean = df.drop(columns=['CUST_ID'])

# %%
df_clean = df_clean.fillna(df_clean.median())

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled = scaler.fit_transform(df_clean)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca_data = pca.fit_transform(scaled)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

input_dim = scaled.shape[1]

# encoder
input_layer = layers.Input(shape=(input_dim,))
encoded = layers.Dense(16, activation='relu')(input_layer)
encoded = layers.Dense(8, activation='relu')(encoded)

# decoder
decoded = layers.Dense(16, activation='relu')(encoded)
decoded = layers.Dense(input_dim, activation='linear')(decoded)

autoencoder = models.Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer='adam', loss='mse')

autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 17)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │           288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 17)             │           289 │
# ...

# %%
autoencoder.fit(scaled, scaled, epochs=30, batch_size=8, validation_split=0.2)
# Out:
# Epoch 1/30
# 895/895 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.7564 - val_loss: 0.2908
# Epoch 2/30
# 895/895 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.3051 - val_loss: 0.1726
# Epoch 3/30
# 895/895 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2259 - val_loss: 0.1229
# Epoch 4/30
# 895/895 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1794 - val_loss: 0.1016
# Epoch 5/30
# 895/895 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1304 - val_loss: 0.1219
# Epoch 6/30
# 895/895 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1120 - val_loss: 0.0926
# Epoch 7/30
# 895/895 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0948 - val_loss: 0.0816
# Epoch 8/30
# 895/895 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1044 - val_loss: 0.0649
# Epoch 9/30
# 895/895 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0794 - val_loss: 0.0605
# Epoch 10/30
# 895/895 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0766 - val_loss: 0.0547
# Epoch 11/30
# 895/895 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0727 - val_loss: 0.0685
# ...

# %%
encoder = models.Model(inputs=input_layer, outputs=encoded)
latent_features = encoder.predict(scaled)
# Out:
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=4)
clusters_dl = kmeans.fit_predict(latent_features)
df['Cluster_DL'] = clusters_dl

# %%
df['Cluster_DL']
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 8945    3
# 8946    3
# 8947    3
# 8948    3
# 8949    3
# Name: Cluster_DL, Length: 8950, dtype: int32

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))
sns.scatterplot(x=pca_data[:, 0], y=pca_data[:, 1], hue=df['Cluster_DL'], palette='viridis', legend='full')
plt.title('Clusters Visualized with PCA (Deep Learning)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()

# %% [markdown]
# # Task
# Calculate and display the Silhouette Score, Davies-Bouldin Score, and Calinski-Harabasz Score to evaluate the quality of the clusters formed using `latent_features` and `clusters_dl`, and summarize the results.

# %% [markdown]
# ## Calculate Clustering Metrics
#
# ### Subtask:
# Calculate Silhouette Score, Davies-Bouldin Score, and Calinski-Harabasz Score to evaluate the quality of the clusters formed using the `latent_features` and `clusters_dl`.

# %% [markdown]
# **Reasoning**:
# The subtask requires calculating the Silhouette Score, Davies-Bouldin Score, and Calinski-Harabasz Score. First, I need to import the necessary functions from `sklearn.metrics`.

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score

# Calculate Silhouette Score
silhouette = silhouette_score(latent_features, clusters_dl)

# Calculate Davies-Bouldin Score
davies_bouldin = davies_bouldin_score(latent_features, clusters_dl)

# Calculate Calinski-Harabasz Score
calinski_harabasz = calinski_harabasz_score(latent_features, clusters_dl)

print(f"Silhouette Score: {silhouette:.4f}")
print(f"Davies-Bouldin Score: {davies_bouldin:.4f}")
print(f"Calinski-Harabasz Score: {calinski_harabasz:.4f}")
# Out:
# Silhouette Score: 0.3064
# Davies-Bouldin Score: 1.3953
# Calinski-Harabasz Score: 3017.0125

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Summarize the results of the clustering evaluation.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# *   The Silhouette Score for the clusters is 0.3064, indicating a reasonable, albeit not exceptionally strong, separation between clusters. Scores closer to 1 suggest better-defined clusters.
# *   The Davies-Bouldin Score is 1.3953. Lower values are desirable, with 0 indicating perfectly separated clusters. This score suggests there is some overlap or less distinct separation between the clusters.
# *   The Calinski-Harabasz Score is 3017.0125. Higher values generally indicate better-defined clusters. This score, in isolation, confirms the presence of discernible cluster structures.
#
# ### Insights or Next Steps
# *   The current clustering solution shows moderate quality based on the evaluation metrics. Consider exploring alternative clustering algorithms or fine-tuning the current algorithm's parameters to achieve better separation and compactness, aiming for higher Silhouette and Calinski-Harabasz scores, and a lower Davies-Bouldin score.
# *   Further investigation into the characteristics of the clusters (e.g., through visualization or feature analysis) could provide context for these scores and help understand if the current clustering aligns with domain-specific expectations, even if the statistical scores are not exceptionally high.
